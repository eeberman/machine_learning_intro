# %%
import pandas as pd

# Load the dataset 
df = pd.read_csv(r"C:\Users\elieberm1\Documents\Python Scripts\machine_learning_self\Ames-Housing-Analysis\Data\Raw\AmesHousing.csv")
print(df.head())
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       5    2010       WD           Normal     215000
# 1        0       6    2010       WD           Normal     105000
# 2    12500       6    2010       WD           Normal     172000
# 3        0       4    2010       WD           Normal     244000
# 4        0       3    2010       WD           Normal     189900
#
# [5 rows x 82 columns]

# %%
# Define the square footage features relevant to living space
square_footage_features = [
    'Gr Liv Area',  # Above ground living area
    'Total Bsmt SF',  # Total basement area
    '1st Flr SF',  # First floor area
    '2nd Flr SF',  # Second floor area, if applicable
    'BsmtFin SF 1',  # Finished basement area 1
    'BsmtFin SF 2',  # Finished basement area 2
    'Bsmt Unf SF',  # Unfinished basement area
    'Low Qual Fin SF'  # Low quality finished area
]

# Calculate the total square footage for living space
df['square_footage_total'] = df[square_footage_features].sum(axis=1)

# Print the selected feature names
print("Features included in square_footage_total:")
print(square_footage_features)

# Print the first few rows of the calculated total square footage
print(df[['square_footage_total']].head(10))
# Out:
# Features included in square_footage_total:
# ['Gr Liv Area', 'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Low Qual Fin SF']
#    square_footage_total
# 0                5472.0
# 1                3556.0
# 2                5316.0
# 3                8440.0
# 4                5114.0
# 5                5060.0
# 6                5352.0
# 7                5120.0
# 8                6422.0
# 9                5596.0

# %%
# Check and redescribe the dataset with square_footage_total included
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# std        1.411026      1.111537    30.245361       20.860286    179.112611
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1965.000000      0.000000
# 50%        6.000000      5.000000  1973.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    164.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        ...  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count  ...    2930.000000     2930.000000  2930.000000   2930.000000
# mean   ...      47.533447       23.011604     2.592491     16.002048
# std    ...      67.483400       64.139059    25.141331     56.087370
# min    ...       0.000000        0.000000     0.000000      0.000000
# 25%    ...       0.000000        0.000000     0.000000      0.000000
# 50%    ...      27.000000        0.000000     0.000000      0.000000
# 75%    ...      70.000000        0.000000     0.000000      0.000000
# max    ...     742.000000     1012.000000   508.000000    576.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice  \
# count  2930.000000   2930.000000  2930.000000  2930.000000    2930.000000
# mean      2.243345     50.635154     6.216041  2007.790444  180796.060068
# std      35.597181    566.344288     2.714492     1.316613   79886.692357
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129500.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  160000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  213500.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
#        square_footage_total
# count           2930.000000
# mean            5101.892150
# std             1610.506496
# min              668.000000
# 25%             4008.000000
# 50%             4904.000000
# 75%             5989.000000
# max            23504.000000
#
# [8 rows x 40 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Select multiple features for the model based totally on intuition
features = ['Lot Area', 'Overall Qual', 'Overall Cond', 'square_footage_total', 'Year Built', 'Pool Area']
X = df[features]
y = df['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create and fit the model 
model = LinearRegression()
model.fit(X_train, y_train)# Make predictions 
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Print the model coefficients
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
# Mean Squared Error: 1694654561.759638
# R-squared: 0.7418729704811233
#                        Coefficient
# Lot Area                  0.786017
# Overall Qual          21323.762533
# Overall Cond           5852.275891
# square_footage_total     23.959591
# Year Built              479.567411
# Pool Area               -40.724840

# %%
from importnb import Notebook

with Notebook():
    import _02_Feature_Engineering
df_combined = _02_Feature_Engineering.df_combined
# Now you can access variables and functions from file_a
print(df_combined.head())
# Out:
#    Lot Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0  2.744381      0.431097     -0.293973    -0.269134       0.064433
# 1  0.187097      0.055696      0.557395    -0.658284      -0.385015
# 2  0.522814      1.054570     -0.293973    -0.348784       0.629649
# 3  0.128458      1.366306     -0.293973     1.105408       2.402474
# 4  0.467348      0.764787     -0.293973    -0.960956      -0.280598
#
#    1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Garage Area  \
# 0    1.267003   -0.783185        -0.101005     0.309265     0.256641
# 1   -0.672643   -0.783185        -0.101005    -1.194427     1.196133
# 2    0.432445   -0.783185        -0.101005    -0.337718    -0.747965
# 3    2.425687   -0.783185        -0.101005     1.207523     0.228735
# 4   -0.590974    0.853432        -0.101005     0.255844     0.042697
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# 0      0.920121       0.214409       -0.358838   -0.103134     -0.285354
# 1      0.366061      -0.704493       -0.358838   -0.103134      1.854530
# 2      2.368594      -0.170937       -0.358838   -0.103134     -0.285354
# 3     -0.742060      -0.704493       -0.358838   -0.103134     -0.285354
# 4      0.935952      -0.200579       -0.358838   -0.103134     -0.285354
#
#    Pool Area  square_footage_total  Order  MS SubClass MS Zoning  \
# 0  -0.063031              0.229848      1           20        RL
# 1  -0.063031             -0.960043      2           20        RH
# 2  -0.063031              0.132967      3           20        RL
# 3  -0.063031              2.073061      4           20        RL
# 4  -0.063031              0.007519      5           60        RL
#
#    Lot Frontage Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0         141.0   Pave    -1       IR1          Lvl    AllPub     Corner
# 1          80.0   Pave    -1       Reg          Lvl    AllPub     Inside
# 2          81.0   Pave    -1       IR1          Lvl    AllPub     Corner
# 3          93.0   Pave    -1       Reg          Lvl    AllPub     Corner
# 4          74.0   Pave    -1       IR1          Lvl    AllPub     Inside
#
#   Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# 0        Gtl        NAmes        Norm        Norm      1Fam      1Story
# 1        Gtl        NAmes       Feedr        Norm      1Fam      1Story
# 2        Gtl        NAmes        Norm        Norm      1Fam      1Story
# 3        Gtl        NAmes        Norm        Norm      1Fam      1Story
# 4        Gtl      Gilbert        Norm        Norm      1Fam      2Story
#
#    Overall Qual  Overall Cond  Year Built  Year Remod/Add Roof Style  \
# 0             6             5        1960            1960        Hip
# 1             5             6        1961            1961      Gable
# 2             6             6        1958            1958        Hip
# 3             7             5        1968            1968        Hip
# 4             5             5        1997            1998      Gable
#
#   Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 0   CompShg      BrkFace      Plywood        Stone         112.0           3
# 1   CompShg      VinylSd      VinylSd           -1           0.0           3
# 2   CompShg      Wd Sdng      Wd Sdng      BrkFace         108.0           3
# 3   CompShg      BrkFace      BrkFace           -1           0.0           4
# 4   CompShg      VinylSd      VinylSd           -1           0.0           3
#
#    Exter Cond Foundation  Bsmt Qual  Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0           3     CBlock        3.0        4.0            Gd            BLQ
# 1           3     CBlock        3.0        3.0            No            Rec
# 2           3     CBlock        3.0        3.0            No            ALQ
# 3           3     CBlock        3.0        3.0            No            ALQ
# 4           3      PConc        4.0        3.0            No            GLQ
#
#   BsmtFin Type 2 Heating Heating QC Central Air Electrical  Bsmt Full Bath  \
# 0            Unf    GasA         Fa           Y      SBrkr             1.0
# 1            LwQ    GasA         TA           Y      SBrkr             0.0
# 2            Unf    GasA         TA           Y      SBrkr             0.0
# 3            Unf    GasA         Ex           Y      SBrkr             1.0
# 4            Unf    GasA         Gd           Y      SBrkr             0.0
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 0             0.0          1          0              3              1
# 1             0.0          1          0              2              1
# 2             0.0          1          1              3              1
# 3             0.0          2          1              3              1
# 4             0.0          2          1              3              1
#
#   Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  Fireplace Qu  \
# 0           TA              7        Typ           2           4.0
# 1           TA              5        Typ           0          -1.0
# 2           Gd              6        Typ           0          -1.0
# 3           Ex              8        Typ           2           3.0
# 4           TA              6        Typ           1           3.0
#
#   Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Qual  \
# 0      Attchd         1960.0           Fin          2.0          3.0
# 1      Attchd         1961.0           Unf          1.0          3.0
# 2      Attchd         1958.0           Unf          1.0          3.0
# 3      Attchd         1968.0           Fin          2.0          3.0
# 4      Attchd         1997.0           Fin          2.0          3.0
#
#    Garage Cond Paved Drive  Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0          3.0           P     -1.0     -1           -1         0        5
# 1          3.0           Y     -1.0  MnPrv           -1         0        6
# 2          3.0           Y     -1.0     -1         Gar2     12500        6
# 3          3.0           Y     -1.0     -1           -1         0        4
# 4          3.0           Y     -1.0  MnPrv           -1         0        3
#
#    Yr Sold Sale Type Sale Condition  SalePrice  Has_Pool  House_Age  \
# 0     2010       WD          Normal     215000         0         50
# 1     2010       WD          Normal     105000         0         49
# 2     2010       WD          Normal     172000         0         52
# 3     2010       WD          Normal     244000         0         42
# 4     2010       WD          Normal     189900         0         13
#
#    Is_Remodeled  Total_Bathrooms  Total_Porch_SF  Has_Garage
# 0             0              2.0       -0.532918           1
# 1             0              1.0        0.688065           1
# 2             0              1.5       -0.918264           0
# 3             0              3.5       -1.451819           1
# 4             1              2.5       -0.947906           1

# %%
# Select multiple features for the model based totally after feature engineering and EDA
features = ['Has_Garage', 'Overall Qual', 'Overall Cond', 'square_footage_total', 'Fireplace Qu', 'Gr Liv Area']
X = df_combined[features]
y = df_combined['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create and fit the model 
model = LinearRegression()
model.fit(X_train, y_train)# Make predictions 
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Print the model coefficients
coefficients = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])
print(coefficients)
# Out:
# Mean Squared Error: 1761098791.4428651
# R-squared: 0.7317522933686191
#                        Coefficient
# Has_Garage            13292.003907
# Overall Qual          24279.418029
# Overall Cond           2128.071144
# square_footage_total  31795.613933
# Fireplace Qu           3167.433867
# Gr Liv Area            4308.589349
